# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
file_path='C:/Users/h/Downloads/5674-833_4th/part2/read_csv_sample.csv'
df=pd.read_csv(file_path, index_col=0, names=['A','B','C','D'])
print(df)
# Out:
#      B   C   D
# A
# c0  c1  c2  c3
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9

# %%
df=pd.read_csv(file_path, header=0)
print(df)
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
file_path='C:/Users/h/Downloads/5674-833_4th/part2/남북한발전전력량.xlsx'
df1=pd.read_excel(file_path, engine='openpyxl')
df2=pd.read_excel(file_path, engine='openpyxl',header=None)
print(df1)
print('-'*30)
print(df2)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
file_path='C:/Users/h/Downloads/5674-833_4th/part2/read_json_sample.json'
df=pd.read_json(file_path)
print(df)
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %%
import html5lib
file_path='C:/Users/h/Downloads/5674-833_4th/part2/sample.html'
df=pd.read_html(file_path)
for i in range(len(df)) :
    print(df[i])
    print('-'*30)
# Out:
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
# ------------------------------
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
# ------------------------------

# %%
from bs4 import BeautifulSoup
import requests
import re

url="https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
resp=requests.get(url)
soup=BeautifulSoup(resp.text,'lxml')
rows=soup.select('div > ul > li')
etfs={}
for row in rows:
    try:
        str=row.text
        ndx=str.index('(')
        etf_name=str[:ndx]
        etf_name=etf_name.strip()
        print(str)
        print(f'etf_name [{etf_name}]')

        ndx1=str.index(':')
        etf_market=str[ndx+1:ndx1]
        etf_market=etf_market.strip()
        print(f'etf_market [{etf_market}]')

        ndx2=str.index(')')
        etf_ticker=str[ndx1+1:ndx2]
        etf_ticker=etf_ticker.strip()
        print(f'etf_ticker [{etf_ticker}]')
        print('-'*30)
        etfs[etf_ticker]=[etf_market, etf_name]
        
    except ValueError  as err:
        pass
    
print(etfs)
print('-'*30)

df=pd.DataFrame(etfs)
print(df)
# Out:
# iShares Core S&P Total US Stock Mkt (NYSE Arca: ITOT)
# etf_name [iShares Core S&P Total US Stock Mkt]
# etf_market [NYSE Arca]
# etf_ticker [ITOT]
# ------------------------------
# iShares MSCI ACWI Index (Nasdaq: ACWI)
# etf_name [iShares MSCI ACWI Index]
# etf_market [Nasdaq]
# etf_ticker [ACWI]
# ------------------------------
# iShares Russell 3000 Index (NYSE Arca: IWV)
# etf_name [iShares Russell 3000 Index]
# etf_market [NYSE Arca]
# etf_ticker [IWV]
# ------------------------------
# Schwab US Broad Market ETF (NYSE Arca: SCHB)
# etf_name [Schwab US Broad Market ETF]
# etf_market [NYSE Arca]
# etf_ticker [SCHB]
# ------------------------------
# Schwab Fundamental U.S. Broad Market Index ETF (NYSE Arca: FNDB)
# etf_name [Schwab Fundamental U.S. Broad Market Index ETF]
# etf_market [NYSE Arca]
# etf_ticker [FNDB]
# ------------------------------
# Vanguard Total World Stock (NYSE Arca: VT), tracks the FTSE All-World Index
# etf_name [Vanguard Total World Stock]
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re

url="https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
resp=requests.get(url)
soup=BeautifulSoup(resp.text,'lxml')
rows=soup.select('div > ul > li')
etfs={}
for row in rows:
    try:
        str=row.text
        ndx=str.find('(')
        if ndx<0: 
            continue
        etf_name=str[:ndx]
        etf_name=etf_name.strip()
        print(str)
        print(f'etf_name [{etf_name}]')

        ndx1=str.find(':',ndx)
        if ndx1>-1:
            etf_market=str[ndx+1:ndx1]
            etf_market=etf_market.strip()

            print(f'etf_market [{etf_market}]')

            ndx2=str.find(')')
            if ndx2<0:
                continue
            etf_ticker=str[ndx1+1:ndx2]
            etf_ticker=etf_ticker.strip()
            print(f'etf_ticker [{etf_ticker}]')
        else:
            ndx2=str.find(')')
            a=str[ndx+1:ndx2]
            ndx1=a.rfind(' ')
            if ndx1>-1:
                etf_market=a[:ndx1]
                print(f'etf_market [{etf_market}]')

                etf_ticker=a[ndx1+1:]
                etf_ticker=etf_ticker.strip()
                print(f'etf_ticker [{etf_ticker}]')

        etfs[etf_ticker]=[etf_market, etf_name]            

    except ValueError  as err:
        print(str(err))
    except Exception as e:
        ptinr(str(e))
    
print(etfs)
print('-'*30)
            
df=pd.DataFrame(etfs)
print(df)
# Out:
# iShares Core S&P Total US Stock Mkt (NYSE Arca: ITOT)
# etf_name [iShares Core S&P Total US Stock Mkt]
# etf_market [NYSE Arca]
# etf_ticker [ITOT]
# iShares MSCI ACWI Index (Nasdaq: ACWI)
# etf_name [iShares MSCI ACWI Index]
# etf_market [Nasdaq]
# etf_ticker [ACWI]
# iShares Russell 3000 Index (NYSE Arca: IWV)
# etf_name [iShares Russell 3000 Index]
# etf_market [NYSE Arca]
# etf_ticker [IWV]
# Schwab US Broad Market ETF (NYSE Arca: SCHB)
# etf_name [Schwab US Broad Market ETF]
# etf_market [NYSE Arca]
# etf_ticker [SCHB]
# Schwab Fundamental U.S. Broad Market Index ETF (NYSE Arca: FNDB)
# etf_name [Schwab Fundamental U.S. Broad Market Index ETF]
# etf_market [NYSE Arca]
# etf_ticker [FNDB]
# Vanguard Total World Stock (NYSE Arca: VT), tracks the FTSE All-World Index
# etf_name [Vanguard Total World Stock]
# etf_market [NYSE Arca]
# etf_ticker [VT]
# Vanguard Total Stock Market (NYSE Arca: VTI), tracks the MSCI US Broad Market Index
# etf_name [Vanguard Total Stock Market]
# ...
